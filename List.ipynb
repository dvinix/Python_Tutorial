# %% [markdown]
# List

# %%
lst=['Mathematics', 'Chemistry', 100, 200, 300]

# %%
len(lst)
# Out:
# 5

# %%
lst.append(400)

# %%
lst
# Out:
# ['Mathematics', 'Chemistry', 100, 200, 300, 400]

# %%
type(lst)
# Out:
# list

# %%
lst[::-1]
# Out:
# [400, 300, 200, 100, 'Chemistry', 'Mathematics']

# %%
lst[1:6]
# Out:
# ['Chemistry', 100, 200, 300, 400]

# %%
lst.append([6,7])

# %%
lst
# Out:
# ['Mathematics', 'Chemistry', 100, 200, 300, 400, [6, 7]]

# %% [raw]
# Extend VS Append

# %%
lst.extend([8,9])

# %%
lst
# Out:
# ['Mathematics', 'Chemistry', 100, 200, 300, 400, [6, 7], 8, 9]

# %%
lst.extend([10])

# %%
lst
# Out:
# ['Mathematics', 'Chemistry', 100, 200, 300, 400, [6, 7], 8, 9, 10]

# %%
lst=[1,2,3,4,5,6,7,8]

# %%
sum(lst)
# Out:
# 36

# %%
lst.pop(-1)
# Out:
# 8

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
lst=[1,2,3,1,2,4,5,6,6,6]

# %%
lst.count(2)
# Out:
# 2

# %%
lst.count(6)
# Out:
# 3

# %%
lst*2
# Out:
# [1, 2, 3, 1, 2, 4, 5, 6, 6, 6, 1, 2, 3, 1, 2, 4, 5, 6, 6, 6]

# %% [markdown]
# SET

# %%
## Defining the set
set_var=set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
set_var={"Avengers", "Ironman", 'Hitman', 1, 2, 2}
print(set_var)
type(set_var)
# Out:
# {1, 2, 'Ironman', 'Hitman', 'Avengers'}
# set

# %%
set("DGFORDG")
# Out:
# {'D', 'F', 'G', 'O', 'R'}

# %%
set_var.add("Hulk")

# %%
set_var
# Out:
# {1, 2, 'Avengers', 'Hitman', 'Hulk', 'Ironman'}

# %% [markdown]
# Dictionaries

# %%
dic={}

# %%
type(dic)
# Out:
# dict

# %%
cars={1:"BMW", 2:"Mercedes" , 3:"Land Rover"}

# %%
cars
# Out:
# {1: 'BMW', 2: 'Mercedes', 3: 'Land Rover'}

# %%
cars[2]
# Out:
# 'Mercedes'

# %%
for x in cars.values():
    print(x)
# Out:
# BMW
# Mercedes
# Land Rover

# %%
cars['car4']='Audi'

# %%
cars
# Out:
# {1: 'BMW', 2: 'Mercedes', 3: 'Land Rover', 'car4': 'Audi'}

# %%
cars
# Out:
# {1: 'BMW', 2: 'Mercedes', 3: 'Land Rover', 'car4': 'Audi'}
